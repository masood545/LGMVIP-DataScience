# %% [markdown]
# ## IMPORT LIBRARIES

# %%
import pandas as pd

import numpy as np

import matplotlib.pyplot as plt

# %matplotlib inline

import seaborn as sns

# %% [markdown]
# ## LOADING THE DATA

# %%
d=pd.read_csv("E:/LETS_GROW_MORE_TASKS/globalterrorism.csv",encoding='iso-8859-1',low_memory=False)

# %% [markdown]
# ## DATA DICTIONARY
#
#
# #### eventid :A 12-digit Event ID system. First 8 numbers – date recorded “yyyymmdd”. Last 4 numbers –sequential
#
# #### iyear :This field contains the year in which the incident occurred.
#
# #### imonth :This field contains the number of the month in which the incident occurred.
#
# #### iday : This field contains the numeric day of the month on which the incident occurred.
#
# #### extended : 1 = "Yes" The duration of an incident extended more than 24 hours.0 = "No" The duration of an incident extended less
#
# #### country :This field identifies the country code
#
# #### country_txt : This field identifies the country or location where the incident occurred.
#
# #### region : This field identifies the region code based on 12 regions
#
# #### region_txt : This field identifies the region in which the incident occurred.
#
# ####  provstate : Name (at the time of event) of the 1st order subnational administrative region
#
# #### city : Name of the city, village, or town in which the incident occurred
#
# #### latitude : The latitude of the city in which the event occurred.
#
# #### longitude :The longitude of the city in which the event occurred.
#
# #### location : location of city where event occured
#
#
# #### multiple : Multiple events at a time
#
# #### success : Success of a terrorist strike
#
# #### suicide : 1 = "Yes" The incident was a suicide attack. 0 = "No" There is no indication that the incident was a suicide
#
# #### attacktype : The general method of attack
#
# #### attacktype_txt : The general method of attack and broad class of tactics used.
#
# #### targtype_txt : The general type of target/victim
#
# #### targsubtype_txt : The more specific target category
#
# #### target : The specific person, building, installation that was targeted and/or victimized
#
# #### natlty1_txt : The nationality of the target that was attacked
#
# #### gname : The name of the group that carried out the attack
#
# #### gsubname : additional details about group that carried out the attack like factions
#
# #### nperps : The total number of terrorists participating in the incident
#
# #### weaptype_txt : General type of weapon used in the incident
#
# #### weapsubtype_txt : More specific value for most of the Weapon Types
#
# #### nkill  : The number of total confirmed fatalities for the incident
#
# #### nkillus :  The number of U.S. citizens who died as a result of the incident

# %% [markdown]
# ## EXPLORATORY DATA  ANALYSIS (EDA)

# %%
d.shape
# Out:
# (181691, 133)

# %% [markdown]
# ### YEARS WITH MOST TERRORIST ATTACKS

# %%
plt.figure(figsize=(8,8))

year=d['iyear'].value_counts().head(10)

sns.barplot(x=year.index,y=year,data=d)

plt.xticks(rotation=45)

plt.title("Years with Most Terrorist Events",fontdict={'family':'serif','color':'green','size':20})

plt.show()

# %% [markdown]
# ## Months With More Terrorist Attacks

# %%
plt.figure(figsize=(8,8))

month=d['imonth'].value_counts().head(12)

sns.barplot(x=month.index,y=month,data=d)


plt.xticks(rotation=45)

plt.title('Months with More Terrorist Attacks',{'family':'serif','color':'green','size':20})

plt.show()

# %%
plt.figure(figsize=(8,8))

months=['January','February','March','April','May','June','July','August','September','October','November','December']

month=list(d['imonth'].value_counts().values[:-1])


plt.pie(x=month,labels=months,autopct='%.0f%%')


plt.title('Months with More Terrorist Attacks',{'family':'serif','color':'green','size':20})


plt.show()

# %%
plt.figure(figsize=(8,8))

day=d['iday'].value_counts().head(10)

sns.barplot(x=day.index,y=day,data=d)



plt.xticks(rotation=45)

plt.title('Days with More Terrorist Attacks',{'family':'serif','color':'green','size':20})

plt.show()

# %%
plt.figure(figsize=(8,8))


extended=d['extended'].value_counts()

label=['Not Extended','Extended']


plt.pie(x=extended,labels=label,autopct='%.0f%%')


plt.title('Extended Vs Not Extended Events',{'family':'serif','color':'green','size':20})


plt.show()

# %%
plt.figure(figsize=(8,8))

country=d['country_txt'].value_counts().head(15)

sns.barplot(x=country.index,y=country,data=d)



plt.xticks(rotation=70)

plt.title('Countries with More Number of Terrorist Attacks',{'family':'serif','color':'purple','size':20})

plt.show()

# %%
plt.figure(figsize=(8,8))


region=d['region_txt'].value_counts().head(9)

label=region.index


plt.pie(x=region,labels=label,autopct='%.0f%%')


plt.title('Popular Regions With More Terrorist Attacks',{'family':'serif','color':'red','size':20})


plt.show()

# %%
plt.figure(figsize=(8,8))


city=d['city'].value_counts().head(10)

label=city.index


plt.pie(x=city,labels=label,autopct='%.0f%%')


plt.title('Popular Cities With More Terrorist Attacks',{'family':'serif','color':'red','size':20})


plt.show()

# %%
plt.figure(figsize=(8,8))


multiple=list(d['multiple'].value_counts().values)

label=['Single Events','Multiple Events']


plt.pie(x=multiple,labels=label,autopct='%.0f%%')


plt.title('Single VS Multiple Attacks AT A Time',{'family':'serif','color':'red','size':20})


plt.show()

# %%
plt.figure(figsize=(8,8))


success=list(d['success'].value_counts().values)

label=['Success Event','Fail Event']


plt.pie(x=success,labels=label,autopct='%.0f%%')


plt.title('Success  VS Fail Attacks',{'family':'serif','color':'brown','size':20})


plt.show()

# %%
plt.figure(figsize=(8,8))


suicide=list(d['suicide'].value_counts().values)

label=['Suicide Event','Non-Suicide Event']


plt.pie(x=suicide,labels=label,autopct='%.0f%%')


plt.title('Suicide   VS Non-Suicide  Events',{'family':'serif','color':'brown','size':20})


plt.show()

# %%
plt.figure(figsize=(8,8))

attack_type=d['attacktype1_txt'].value_counts()

sns.barplot(x=attack_type.index,y=attack_type,data=d)



plt.xticks(rotation=70)

plt.title('Type Of Attacks',{'family':'serif','color':'green','size':20})

plt.show()

# %%
plt.figure(figsize=(8,8))

targettype=d['targtype1_txt'].value_counts().head(10)

sns.barplot(x=targettype.index,y=targettype,data=d)



plt.xticks(rotation=70)

plt.title('Type Of Targets',{'family':'serif','color':'green','size':20})

plt.show()

# %%
plt.figure(figsize=(8,8))

target=d['target3'].value_counts().head(10)

sns.barplot(x=target.index,y=target,data=d)



plt.xticks(rotation=70)

plt.title('Specific Type Of Targets',{'family':'serif','color':'green','size':20})

plt.show()

# %%
plt.figure(figsize=(8,8))

natlty=d['natlty1_txt'].value_counts().head(10)

sns.barplot(x=natlty.index,y=natlty,data=d)



plt.xticks(rotation=70)

plt.title('Nationality Of Targeted People',{'family':'serif','color':'green','size':20})

plt.show()

# %%
plt.figure(figsize=(8,8))

group=d['gname'].value_counts().head(10)

sns.barplot(y=group.index,x=group,data=d)



plt.xticks(rotation=0)

plt.title('Name Of The Group Involved In Attack',{'family':'serif','color':'red','size':20})

plt.show()

# %%
plt.figure(figsize=(8,8))

i=list(d['nperps'].value_counts().head(11).index)[1:]

npreps=list(d['nperps'].value_counts().head(11).values)[1:]

sns.barplot(x=i,y=nperps,data=d)



plt.xticks(rotation=70)

plt.title('Number of terrorists participating in the incident ',{'family':'serif','color':'green','size':20})

plt.show()

# %%
plt.figure(figsize=(8,8))

weapon=d['weaptype1_txt'].value_counts().head(5)

sns.barplot(y=weapon.index,x=weapon,data=d)



plt.xticks(rotation=0)

plt.title('Type Of Weapons Used',{'family':'serif','color':'black','size':20})

plt.show()

# %%
plt.figure(figsize=(8,8))

nkill=d['nkill'].value_counts().head(10)

sns.barplot(x=nkill.index,y=nkill,data=d)



plt.xticks(rotation=70)

plt.title('Number Of People Killed ',{'family':'serif','color':'green','size':20})

plt.show()

# %%
plt.figure(figsize=(8,8))


nkillus=d['nkillus'].value_counts().head(2).values

label=['Zero Citizen','One Citizen']


plt.pie(x=nkillus,labels=label,autopct='%.0f%%')


plt.title('Number of U.S. citizens who died as a result of the incident',{'family':'serif','color':'green','size':20})

plt.show()
